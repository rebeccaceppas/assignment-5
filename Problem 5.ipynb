# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mydata = '/Users/rebeccaceppas/Downloads/CeppasdeCastroRebecca.dat'
data = np.loadtxt(mydata)
print(data)
# Out:
# [[6.02926864e+02 7.93339706e+04]
#  [6.05737546e+02 7.12776308e+04]
#  [3.02202107e+02 3.76350617e+04]
#  [2.47397966e+02 3.15597139e+04]
#  [7.91970510e+02 9.50538063e+04]
#  [7.02003194e+02 8.77866161e+04]
#  [4.13794761e+02 5.16717064e+04]
#  [3.79142309e+02 4.87495630e+04]
#  [9.41970916e+02 1.06906820e+05]
#  [9.35232553e+02 9.89620526e+04]
#  [2.52923688e+02 2.85311284e+04]
#  [5.04004552e+02 6.52744304e+04]
#  [8.86184508e+02 1.23248509e+05]
#  [8.82356828e+02 1.11143355e+05]
#  [1.40373668e+02 1.76475669e+04]
#  [6.17324398e+02 7.44498706e+04]
#  [6.44753333e+02 8.19446958e+04]
#  [3.08241115e+02 3.58661732e+04]
#  [7.05043228e+02 8.85503740e+04]
#  [4.87673851e+01 5.25000183e+03]
#  [5.82355665e+02 7.14997323e+04]
#  [8.01833259e+01 1.00074152e+04]
#  [5.77314847e+02 6.77992570e+04]
#  [3.74644966e+02 4.15607244e+04]
#  [8.64744095e+02 1.17434663e+05]
#  [8.02707404e+02 9.04677194e+04]
#  [1.12391390e+02 1.35961101e+04]
#  [6.21563064e+02 8.55204453e+04]
# ...

# %%
pd_mpc, v_kms = np.loadtxt(mydata,unpack=True)

# %%
plt.scatter(pd_mpc, v_kms, s=50, color="blue", alpha=0.8)
plt.xlabel("Proper distance (Mpc)",fontsize=15)
plt.ylabel("Velocity (km/s)",fontsize=15)
plt.title("Velocity vs Proper Distance",fontsize=20)
plt.show()

# %% [markdown]
# To determine the present day value of this alterate Universe's Hubble parameter, we find the line of best fit in the graph.

# %%
np.polyfit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-da1aab10c822> in <module>
# ----> 1 np.polyfit()
#
# <__array_function__ internals> in polyfit(*args, **kwargs)
#
# TypeError: _polyfit_dispatcher() missing 3 required positional arguments: 'x', 'y', and 'deg'
